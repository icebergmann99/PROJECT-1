# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates
import datetime as dt
import os

#environment variable set int command/git bash with:  export gkey=keyfromgoogle
#pull in environment variable, neet to import os for this to work
gkey = os.getenv("gkey")

# The path to our CSV file
file = "Resources/Metro_Crash_Clean.csv"

# Read our CSV data into pandas
df = pd.read_csv(file, parse_dates = ['Date and Time'],low_memory=False)
df.head()
# Out:
#    Unnamed: 0 Accident Number       Date and Time  Number of Motor Vehicles  \
# 0       12373     20190402257 2019-05-26 12:41:00                       2.0
# 1       12374     20190397714 2019-05-24 13:15:00                       2.0
# 2       12378     20190413063 2019-05-30 13:23:00                       2.0
# 3       12379     20190415612 2019-05-31 08:45:00                       2.0
# 4       12380     20190413788 2019-05-30 00:00:00                       1.0
#
#    Number of Injuries  Number of Fatalities Property Damage Hit and Run  \
# 0                 2.0                   0.0             NaN           N
# 1                 0.0                   0.0             NaN           Y
# 2                 1.0                   0.0             NaN           N
# 3                 0.0                   0.0             NaN           N
# 4                 0.0                   0.0               Y           Y
#
#   Reporting Officer  Collision Type Code  ... State      ZIP      RPA  \
# 0            769379                  4.0  ...    TN  37211.0   8889.0
# 1            299238                  5.0  ...    TN  37207.0  19060.0
# 2            225777                  4.0  ...    TN  37209.0   4696.0
# 3            179580                  5.0  ...    TN  37208.0   5415.0
# 4            240955                  0.0  ...    TN  37013.0   8767.0
#
#    Precinct Latitude Longitude      Mapped Location month_year  Year Month
# 0     SOUTH  36.0868  -86.6959  (36.0868, -86.6959)    2019-05  2019     5
# 1      EAST  36.1922  -86.7755  (36.1922, -86.7755)    2019-05  2019     5
# 2      WEST  36.1530  -86.8576   (36.153, -86.8576)    2019-05  2019     5
# 3     NORTH  36.1707  -86.8013  (36.1707, -86.8013)    2019-05  2019     5
# 4     SOUTH  35.9955  -86.6879  (35.9955, -86.6879)    2019-05  2019     5
#
# [5 rows x 29 columns]

# %%
##Must do for this in git bash / command line to run:
    #pip install gmaps
    #jupyter nbextension enable --py gmaps

#Initial setup help https://medium.com/future-vision/google-maps-in-python-part-2-393f96196eaf
#GMAPS documentation https://jupyter-gmaps.readthedocs.io/en/latest/

import gmaps

gmaps.configure(api_key=gkey)

#geo for center of nashville
nashville_center = (36.1960, -86.7994)

#defines how the image looks, can set height/width with number of pixels ex. 400px
figure_layout = {
    'width': '600px',
    'height': '600px',
    'border': '1px solid black',
    'padding': '1px'}

#defines locations ad the combination of the latitude and longitude fields
locations = df[["Latitude", "Longitude"]]

#sets the baseline figure
fig = gmaps.figure(map_type="TERRAIN", layout=figure_layout, center=nashville_center, zoom_level=10)
#map types are ROADMAP, SATELLITE, HYBRID, and TERRAIN

#builds heatmap off of the dataframe
heatmap_layer = gmaps.heatmap_layer(locations)

#adds heatmap to the figure
fig.add_layer(heatmap_layer)

#displays the figure
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='600px', padding='1px', width='600px'))

# %%
#heatmap settings can be modified after displaying in the cell above.  
heatmap_layer.max_intensity = 100
heatmap_layer.point_radius = 5
#heatmap_layer.gradient = [(101,67,33),(0,255,0),(255,103,0)]
#heatmap_layer.gradient = ["green","blue","red"]

#color gradiants tend to color whole map but look good.
heatmap_layer.opacity = 0.7

# %%
# The path to our CSV file
filed = "Resources/nashville-crash-data-deer.csv"

# Read our CSV data into pandas
dfd = pd.read_csv(filed, parse_dates = ['Date and Time'],low_memory=False)
dfd.head()

#need to clean data, NaN in Lat/Long columns
# Out:
#    Accident Number       Date and Time  Number of Motor Vehicles  \
# 0      20160863376 2016-09-26 01:56:00                       1.0
# 1      20150533956 2015-06-05 23:37:00                       1.0
# 2      20170737900 2017-08-19 23:55:00                       1.0
# 3      20180276556 2018-03-26 23:32:00                       1.0
# 4      20170438250 2017-05-18 00:43:00                       1.0
#
#    Number of Injuries  Number of Fatalities Property Damage Hit and Run  \
# 0                 1.0                   0.0               Y           N
# 1                 1.0                   0.0               Y           N
# 2                 0.0                   0.0               Y           N
# 3                 0.0                   0.0               Y           N
# 4                 1.0                   0.0               Y           N
#
#   Reporting Officer  Collision Type Code  \
# 0            212316                  0.0
# 1            134898                  0.0
# 2            212325                  0.0
# 3            212310                  0.0
# 4            256499                  0.0
#
#                 Collision Type Description  ...  \
# 0  NOT COLLISION W/MOTOR VEHICLE-TRANSPORT  ...
# 1  NOT COLLISION W/MOTOR VEHICLE-TRANSPORT  ...
# 2  NOT COLLISION W/MOTOR VEHICLE-TRANSPORT  ...
# 3  NOT COLLISION W/MOTOR VEHICLE-TRANSPORT  ...
# 4  NOT COLLISION W/MOTOR VEHICLE-TRANSPORT  ...
#
#                    Harmful Code Description  \
# 0                     CULVERT;DEER (ANIMAL)
# 1  CULVERT;DEER (ANIMAL);Ran Off Road-Right
# 2  CULVERT;DEER (ANIMAL);Ran Off Road-Right
# 3               CULVERT;DITCH;DEER (ANIMAL)
# 4                CULVERT;TREE;DEER (ANIMAL)
#
#                              Street Address            City State      ZIP  \
# 0           BRICK CHURCH PKE & DRY CREEK RD  GOODLETTSVILLE    TN  37072.0
# 1  GRANNY WHITE PIKE & CARL SEYFERT MEMORIA       NASHVILLE    TN  37220.0
# 2                   UPLAND DR & ROSEBANK AV       NASHVILLE    TN  37216.0
# 3             RAWLINGS RD & EATONS CREEK RD         JOELTON    TN  37080.0
# 4                    PRESTON RD & PETTUS RD         ANTIOCH    TN  37013.0
#
#       RPA Precinct Latitude Longitude      Mapped Location
# 0  2125.0   MADISO  36.3280  -86.7648   (36.328, -86.7648)
# 1  7111.0   MIDTOW  36.0593  -86.8151  (36.0593, -86.8151)
# 2  1409.0     EAST  36.1982  -86.7065  (36.1982, -86.7065)
# 3  3329.0    NORTH  36.3113  -86.8798  (36.3113, -86.8798)
# 4  8763.0    SOUTH  36.0258  -86.6630   (36.0258, -86.663)
#
# [5 rows x 25 columns]

# %%
#plotting the deer map
#defines locations ad the combination of the latitude and longitude fields
locations = dfd[["Latitude", "Longitude"]]

#sets the baseline figure
figd = gmaps.figure(map_type="ROADMAP", layout=figure_layout, center=nashville_center, zoom_level=10)
#map types are ROADMAP, SATELLITE, HYBRID, and TERRAIN

#builds heatmap off of the dataframe
heatmap_layer = gmaps.heatmap_layer(locations)

#adds heatmap to the figure
figd.add_layer(heatmap_layer)

#displays the figure
figd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\gmaps\locations.py in locations_to_list(locations)
#      10     try:
# ---> 11         location_tuples = locations.itertuples()  # locations is a dataframe
#      12         locations_as_list = [
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#
# AttributeError: 'Series' object has no attribute 'itertuples'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-f888ed266dbe> in <module>
#       7
#       8 #builds heatmap off of the dataframe
# ----> 9 heatmap_layer = gmaps.heatmap_layer(locations)
#      10
#      11 #adds heatmap to the figure
#
# ~\Anaconda3\lib\site-packages\gmaps\heatmap.py in heatmap_layer(locations, weights, max_intensity, dissipating, point_radius, opacity, gradient)
#     269         return WeightedHeatmap(**widget_args)
#     270     else:
# --> 271         return Heatmap(**widget_args)
#
# ~\Anaconda3\lib\site-packages\ipywidgets\widgets\widget.py in __init__(self, **kwargs)
#     408         """Public constructor"""
#     409         self._model_id = kwargs.pop('model_id', None)
# --> 410         super(Widget, self).__init__(**kwargs)
#     411
#     412         Widget._call_widget_constructed(self)
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in __init__(self, *args, **kwargs)
#     995             for key, value in kwargs.items():
#     996                 if self.has_trait(key):
# --> 997                     setattr(self, key, value)
#     998                 else:
#     999                     # passthrough args that don't set traits to super
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     557
#     558     def set(self, obj, value):
# --> 559         new_value = self._validate(obj, value)
#     560         try:
#     561             old_value = obj._trait_values[self.name]
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in _validate(self, obj, value)
#     589             return value
#     590         if hasattr(self, 'validate'):
# --> 591             value = self.validate(obj, value)
#     592         if obj._cross_validation_lock is False:
#     593             value = self._cross_validate(obj, value)
#
# ~\Anaconda3\lib\site-packages\gmaps\geotraitlets.py in validate(self, obj, value)
#      22         if value is None:
#      23             return super(LocationArray, self).validate(obj, value)
# ---> 24         locations_as_list = locations_to_list(value)
#      25         for location in locations_as_list:
#      26             latitude, longitude = location
#
# ~\Anaconda3\lib\site-packages\gmaps\locations.py in locations_to_list(locations)
#      17         locations_as_list = [
#      18             (latitude, longitude) for (latitude, longitude)
# ---> 19             in locations
#      20         ]
#      21     return locations_as_list
#
# ~\Anaconda3\lib\site-packages\gmaps\locations.py in <listcomp>(.0)
#      16     except AttributeError:
#      17         locations_as_list = [
# ---> 18             (latitude, longitude) for (latitude, longitude)
#      19             in locations
#      20         ]
#
# ValueError: too many values to unpack (expected 2)
